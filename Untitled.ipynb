# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import keras
from keras import backend as k
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout, BatchNormalization
from keras.optimizers import Adamax
from collections import Counter
import random
import music21
from music21 import *
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import os
# Out:
# WARNING:tensorflow:From C:\Users\mayal\anaconda3\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
np.random.seed(45)
## BEGINING OF LOADING THE DATA 

filepath = "training_data/Guitar/" 

all_midis= []
for i in os.listdir(filepath):
    if i.endswith(".mid"):
        tr = filepath+i
        midi = converter.parse(tr)
        all_midis.append(midi)
            
def extract_notes(file):
    notes = []
    pick = None
    for j in file:
        songs = instrument.partitionByInstrument(j)
        for part in songs.parts:
            pick = part.recurse()
            for element in pick:
                if isinstance(element, note.Note):
                    notes.append(str(element.pitch))
                elif isinstance(element, chord.Chord):
                    notes.append(".".join(str(n) for n in element.normalOrder))

    return notes

Corpus= extract_notes(all_midis)
print("# of Notes in the piano dataset:", len(Corpus))

def chords_n_notes(Snippet):
    Melody = []
    offset = 0 #Incremental
    for i in Snippet:
        #If it is chord
        if ("." in i or i.isdigit()):
            chord_notes = i.split(".") #Seperating the notes in chord
            notes = [] 
            for j in chord_notes:
                inst_note=int(j)
                note_snip = note.Note(inst_note)            
                notes.append(note_snip)
                chord_snip = chord.Chord(notes)
                chord_snip.offset = offset
                Melody.append(chord_snip)
        # pattern is a note
        else: 
            note_snip = note.Note(i)
            note_snip.offset = offset
            Melody.append(note_snip)
        # increase offset each iteration so that notes do not stack
        offset += 1
    Melody_midi = stream.Stream(Melody)   
    return Melody_midi

#Creating a count dictionary
count_num = Counter(Corpus)
print("Total unique notes in the Corpus:", len(count_num))

Notes = list(count_num.keys())
Recurrence = list(count_num.values())
print("Average recurrenc for a note in Corpus:", sum(Recurrence) / len(Recurrence))
print("Most frequent note in Corpus appeared:", max(Recurrence), "times")
print("Least frequent note in Corpus appeared:", min(Recurrence), "time")

# Set a seaborn style
sns.set_style("whitegrid")

# Plotting the distribution of Notes
plt.figure(figsize=(12, 6), facecolor="#FFD1DC")
bins = np.arange(0, len(Recurrence) + 1, 1)
plt.hist(range(len(Recurrence)), bins=bins, weights=Recurrence, color="#CF578A", edgecolor="white", alpha=0.7)
plt.axhline(y=100, color="#DBACC1", linestyle="--", linewidth=2, label="Threshold")
plt.title("Frequency of Notes in the Corpus", fontsize=16)
plt.xlabel("Note ID (Number associated to note)", fontsize=12)
plt.ylabel("Times it appears in the Corpus", fontsize=12)
plt.legend()
plt.grid(axis="x", linestyle="--", alpha=0.7)
plt.show()

rare_note = []
for index, (key, value) in enumerate(count_num.items()):
    if value < 100:
        m =  key
        rare_note.append(m)
        
print("Total number of notes that occur less than 100 times:", len(rare_note))

for element in Corpus:
    if element in rare_note:
        Corpus.remove(element)

print("Length of Corpus after elemination the rare notes:", len(Corpus))
# Out:
# # of Notes in the piano dataset: 16295
# Total unique notes in the Corpus: 175
# Average recurrenc for a note in Corpus: 93.11428571428571
# Most frequent note in Corpus appeared: 1061 times
# Least frequent note in Corpus appeared: 1 time
# Total number of notes that occur less than 100 times: 138
# Length of Corpus after elemination the rare notes: 14458

# %%
## BEGINING OF PREPROCESSING

symb = sorted(list(set(Corpus)))

L_corpus = len(Corpus) #length of corpus
L_symb = len(symb) #length of total unique characters

#Building dictionary to access the vocabulary from indices and vice versa
mapping = dict((c, i) for i, c in enumerate(symb))
reverse_mapping = dict((i, c) for i, c in enumerate(symb))

print("Total number of characters:", L_corpus)
print("Number of unique characters:", L_symb)

#Splitting the Corpus in equal length of strings and output target
length = 40
features = []
targets = []
for i in range(0, L_corpus - length, 1):
    feature = Corpus[i:i + length]
    target = Corpus[i + length]
    features.append([mapping[j] for j in feature])
    targets.append(mapping[target])
    
L_datapoints = len(targets)
print("Total number of sequences in the Corpus:", L_datapoints)

# reshape X and normalize
X = (np.reshape(features, (L_datapoints, length, 1)))/ float(L_symb)

# one hot encode the output variable
y = tf.keras.utils.to_categorical(targets) 

#Taking out a subset of data to be used as seed
X_train, X_seed, y_train, y_seed = train_test_split(X, y, test_size=0.5, random_state=45)
# Out:
# Total number of characters: 14458
# Number of unique characters: 121
# Total number of sequences in the Corpus: 14418

# %%
## BEGINING OF MODEL IMPLEMENTAITON
model_file_path = "prev_model.keras"

if os.path.exists(model_file_path):
    model = keras.models.load_model(model_file_path)
else:
    model = Sequential()
    model.add(LSTM(512, input_shape=(X.shape[1], X.shape[2]), return_sequences=True))
    model.add(Dropout(0.1))
    model.add(BatchNormalization())
    model.add(LSTM(256))
    model.add(Dense(256))
    model.add(BatchNormalization())
    model.add(Dropout(0.1))
    model.add(Dense(y.shape[1], activation='softmax'))
    
    opt = Adamax(learning_rate=0.01)
    model.compile(loss='categorical_crossentropy', optimizer=opt) 

    history = model.fit(X_train, y_train, batch_size=350, epochs=150)
    model.save("new_model.keras")
    history_df = pd.DataFrame(history.history)
    history_df.to_csv('training_history.csv', index=False)
    
    # Plotting the learning plot for model loss
    plt.figure(figsize=(15, 4), facecolor="#FFD1DC")
    plt.title("Learning Evaluation: Loss over epoch", fontsize=16)
    sns.lineplot(data=history_df["loss"], color="#CF578A", linewidth=2)
    plt.ylabel("Training Loss", fontsize=12)
    plt.xlabel("Number of epoch", fontsize=12)
    plt.grid(axis="y", linestyle="--", alpha=0.7)
    plt.show()

model.summary()
# Out:
# Epoch 1/150
# 21/21 [==============================] - 25s 1s/step - loss: 5.0581
# Epoch 2/150
# 21/21 [==============================] - 21s 1s/step - loss: 4.0554
# Epoch 3/150
# 21/21 [==============================] - 22s 1s/step - loss: 3.7288
# Epoch 4/150
# 21/21 [==============================] - 22s 1s/step - loss: 3.6711
# Epoch 5/150
# 21/21 [==============================] - 22s 1s/step - loss: 3.6063
# Epoch 6/150
# 21/21 [==============================] - 24s 1s/step - loss: 3.5933
# Epoch 7/150
# 21/21 [==============================] - 22s 1s/step - loss: 3.5944
# Epoch 8/150
# 21/21 [==============================] - 23s 1s/step - loss: 3.5944
# Epoch 9/150
# 21/21 [==============================] - 26s 1s/step - loss: 3.5930
# Epoch 10/150
# 21/21 [==============================] - 25s 1s/step - loss: 3.5942
# Epoch 11/150
# 21/21 [==============================] - 24s 1s/step - loss: 3.5929
# Epoch 12/150
# 21/21 [==============================] - 25s 1s/step - loss: 3.5935
# Epoch 13/150
# 21/21 [==============================] - 25s 1s/step - loss: 3.5936
# Epoch 14/150
# 21/21 [==============================] - 26s 1s/step - loss: 3.5922
# Epoch 15/150
# 21/21 [==============================] - 23s 1s/step - loss: 3.5952
# Epoch 16/150
# 21/21 [==============================] - 24s 1s/step - loss: 3.5940
# Epoch 17/150
# 21/21 [==============================] - 23s 1s/step - loss: 3.5913
# Epoch 18/150
# 21/21 [==============================] - 24s 1s/step - loss: 3.5945
# Epoch 19/150
# 21/21 [==============================] - 24s 1s/step - loss: 3.5931
# Epoch 20/150
# 21/21 [==============================] - 24s 1s/step - loss: 3.5933
# Epoch 21/150
# 21/21 [==============================] - 25s 1s/step - loss: 3.5943
# Epoch 22/150
# 21/21 [==============================] - 25s 1s/step - loss: 3.5947
# Epoch 23/150
# 21/21 [==============================] - 23s 1s/step - loss: 3.5930
# Epoch 24/150
# 21/21 [==============================] - 24s 1s/step - loss: 3.5931
# Epoch 25/150
# 21/21 [==============================] - 25s 1s/step - loss: 3.5957
# Epoch 26/150
# 21/21 [==============================] - 23s 1s/step - loss: 3.5928
# Epoch 27/150
# 21/21 [==============================] - 23s 1s/step - loss: 3.5933
# Epoch 28/150
# 21/21 [==============================] - 26s 1s/step - loss: 3.5938
# Epoch 29/150
# 21/21 [==============================] - 25s 1s/step - loss: 3.5934
# Epoch 30/150
# 21/21 [==============================] - 25s 1s/step - loss: 3.5946
# Epoch 31/150
# 21/21 [==============================] - 24s 1s/step - loss: 3.5915
# Epoch 32/150
# 21/21 [==============================] - 24s 1s/step - loss: 3.5941
# Epoch 33/150
# 21/21 [==============================] - 23s 1s/step - loss: 3.5934
# Epoch 34/150
# 21/21 [==============================] - 22s 1s/step - loss: 3.5956
# Epoch 35/150
# 21/21 [==============================] - 23s 1s/step - loss: 3.5926
# Epoch 36/150
# 21/21 [==============================] - 22s 1s/step - loss: 3.5928
# Epoch 37/150
# 21/21 [==============================] - 21s 1s/step - loss: 3.5913
# Epoch 38/150
# 21/21 [==============================] - 23s 1s/step - loss: 3.5928
# Epoch 39/150
# 21/21 [==============================] - 23s 1s/step - loss: 3.5935
# Epoch 40/150
# 21/21 [==============================] - 24s 1s/step - loss: 3.5922
# Epoch 41/150
# 21/21 [==============================] - 24s 1s/step - loss: 3.5936
# Epoch 42/150
# 21/21 [==============================] - 22s 1s/step - loss: 3.5935
# Epoch 43/150
# 21/21 [==============================] - 22s 1s/step - loss: 3.5929
# Epoch 44/150
# 21/21 [==============================] - 24s 1s/step - loss: 3.5940
# Epoch 45/150
# 21/21 [==============================] - 21s 1s/step - loss: 3.5931
# Epoch 46/150
# 21/21 [==============================] - 23s 1s/step - loss: 3.5941
# Epoch 47/150
# 21/21 [==============================] - 24s 1s/step - loss: 3.5937
# Epoch 48/150
# 21/21 [==============================] - 24s 1s/step - loss: 3.5922
# Epoch 49/150
# 21/21 [==============================] - 23s 1s/step - loss: 3.5914
# Epoch 50/150
# 21/21 [==============================] - 24s 1s/step - loss: 3.5929
# Epoch 51/150
# 21/21 [==============================] - 24s 1s/step - loss: 3.5913
# Epoch 52/150
# 21/21 [==============================] - 23s 1s/step - loss: 3.5942
# Epoch 53/150
# 21/21 [==============================] - 22s 1s/step - loss: 3.5927
# Epoch 54/150
# 21/21 [==============================] - 23s 1s/step - loss: 3.5917
# Epoch 55/150
# 21/21 [==============================] - 23s 1s/step - loss: 3.5939
# Epoch 56/150
# 21/21 [==============================] - 23s 1s/step - loss: 3.5941
# Epoch 57/150
# 21/21 [==============================] - 23s 1s/step - loss: 3.5948
# Epoch 58/150
# 21/21 [==============================] - 24s 1s/step - loss: 3.5931
# Epoch 59/150
# 21/21 [==============================] - 24s 1s/step - loss: 3.5932
# Epoch 60/150
# 21/21 [==============================] - 25s 1s/step - loss: 3.5929
# Epoch 61/150
# 21/21 [==============================] - 24s 1s/step - loss: 3.5916
# Epoch 62/150
# 21/21 [==============================] - 23s 1s/step - loss: 3.5947
# Epoch 63/150
# 21/21 [==============================] - 22s 1s/step - loss: 3.5933
# Epoch 64/150
# 21/21 [==============================] - 24s 1s/step - loss: 3.5930
# Epoch 65/150
# 21/21 [==============================] - 25s 1s/step - loss: 3.5928
# Epoch 66/150
# 21/21 [==============================] - 26s 1s/step - loss: 3.5914
# Epoch 67/150
# 21/21 [==============================] - 24s 1s/step - loss: 3.5924
# Epoch 68/150
# 21/21 [==============================] - 23s 1s/step - loss: 3.5905
# Epoch 69/150
# 21/21 [==============================] - 24s 1s/step - loss: 3.5923
# Epoch 70/150
# 21/21 [==============================] - 24s 1s/step - loss: 3.5921
# Epoch 71/150
# 21/21 [==============================] - 22s 1s/step - loss: 3.5920
# Epoch 72/150
# 21/21 [==============================] - 22s 1s/step - loss: 3.5933
# Epoch 73/150
# 21/21 [==============================] - 24s 1s/step - loss: 3.5935
# Epoch 74/150
# 21/21 [==============================] - 22s 1s/step - loss: 3.5924
# Epoch 75/150
# 21/21 [==============================] - 23s 1s/step - loss: 3.5928
# Epoch 76/150
# 21/21 [==============================] - 22s 1s/step - loss: 3.5921
# Epoch 77/150
# 21/21 [==============================] - 23s 1s/step - loss: 3.5910
# Epoch 78/150
# 21/21 [==============================] - 23s 1s/step - loss: 3.5941
# Epoch 79/150
# 21/21 [==============================] - 22s 1s/step - loss: 3.5872
# Epoch 80/150
# 21/21 [==============================] - 23s 1s/step - loss: 3.5888
# Epoch 81/150
# 21/21 [==============================] - 23s 1s/step - loss: 3.5919
# Epoch 82/150
# 21/21 [==============================] - 23s 1s/step - loss: 3.5866
# Epoch 83/150
# 21/21 [==============================] - 24s 1s/step - loss: 3.5843
# Epoch 84/150
# 21/21 [==============================] - 22s 1s/step - loss: 3.5823
# Epoch 85/150
# 21/21 [==============================] - 23s 1s/step - loss: 3.5492
# Epoch 86/150
# 21/21 [==============================] - 21s 991ms/step - loss: 3.5332
# Epoch 87/150
# 21/21 [==============================] - 21s 1s/step - loss: 3.5282
# Epoch 88/150
# 21/21 [==============================] - 21s 1s/step - loss: 3.5198
# Epoch 89/150
# 21/21 [==============================] - 22s 1s/step - loss: 3.5174
# Epoch 90/150
# 21/21 [==============================] - 22s 1s/step - loss: 3.5079
# Epoch 91/150
# 21/21 [==============================] - 21s 1s/step - loss: 3.5087
# Epoch 92/150
# 21/21 [==============================] - 22s 1s/step - loss: 3.5096
# Epoch 93/150
# 21/21 [==============================] - 24s 1s/step - loss: 3.5033
# Epoch 94/150
# 21/21 [==============================] - 24s 1s/step - loss: 3.5022
# Epoch 95/150
# 21/21 [==============================] - 23s 1s/step - loss: 3.4953
# Epoch 96/150
# 21/21 [==============================] - 24s 1s/step - loss: 3.4951
# Epoch 97/150
# 21/21 [==============================] - 21s 1s/step - loss: 3.4948
# Epoch 98/150
# 21/21 [==============================] - 25s 1s/step - loss: 3.4911
# Epoch 99/150
# 21/21 [==============================] - 25s 1s/step - loss: 3.4881
# Epoch 100/150
# 21/21 [==============================] - 25s 1s/step - loss: 3.4864
# Epoch 101/150
# 21/21 [==============================] - 24s 1s/step - loss: 3.4893
# Epoch 102/150
# 21/21 [==============================] - 24s 1s/step - loss: 3.4774
# Epoch 103/150
# 21/21 [==============================] - 24s 1s/step - loss: 3.4808
# Epoch 104/150
# 21/21 [==============================] - 24s 1s/step - loss: 3.4791
# Epoch 105/150
# 21/21 [==============================] - 25s 1s/step - loss: 3.4759
# Epoch 106/150
# 21/21 [==============================] - 24s 1s/step - loss: 3.4810
# Epoch 107/150
# 21/21 [==============================] - 26s 1s/step - loss: 3.4694
# Epoch 108/150
# 21/21 [==============================] - 25s 1s/step - loss: 3.4694
# Epoch 109/150
# 21/21 [==============================] - 22s 1s/step - loss: 3.4758
# Epoch 110/150
# 21/21 [==============================] - 22s 1s/step - loss: 3.4705
# Epoch 111/150
# 21/21 [==============================] - 25s 1s/step - loss: 3.4696
# Epoch 112/150
# 21/21 [==============================] - 21s 1s/step - loss: 3.4674
# Epoch 113/150
# 21/21 [==============================] - 21s 1s/step - loss: 3.4710
# Epoch 114/150
# 21/21 [==============================] - 21s 1s/step - loss: 3.4665
# Epoch 115/150
# 21/21 [==============================] - 22s 1s/step - loss: 3.4595
# Epoch 116/150
# 21/21 [==============================] - 22s 1s/step - loss: 3.4653
# Epoch 117/150
# 21/21 [==============================] - 24s 1s/step - loss: 3.4591
# Epoch 118/150
# 21/21 [==============================] - 24s 1s/step - loss: 3.4568
# Epoch 119/150
# 21/21 [==============================] - 24s 1s/step - loss: 3.4558
# Epoch 120/150
# 21/21 [==============================] - 24s 1s/step - loss: 3.4567
# Epoch 121/150
# 21/21 [==============================] - 24s 1s/step - loss: 3.4536
# Epoch 122/150
# 21/21 [==============================] - 25s 1s/step - loss: 3.4854
# Epoch 123/150
# 21/21 [==============================] - 24s 1s/step - loss: 3.4809
# Epoch 124/150
# 21/21 [==============================] - 25s 1s/step - loss: 3.4642
# Epoch 125/150
# 21/21 [==============================] - 25s 1s/step - loss: 3.4697
# Epoch 126/150
# 21/21 [==============================] - 25s 1s/step - loss: 3.4615
# Epoch 127/150
# 21/21 [==============================] - 24s 1s/step - loss: 3.4609
# Epoch 128/150
# 21/21 [==============================] - 25s 1s/step - loss: 3.4632
# Epoch 129/150
# 21/21 [==============================] - 27s 1s/step - loss: 3.4459
# Epoch 130/150
# 21/21 [==============================] - 26s 1s/step - loss: 3.4507
# Epoch 131/150
# 21/21 [==============================] - 24s 1s/step - loss: 3.4647
# Epoch 132/150
# 21/21 [==============================] - 21s 1s/step - loss: 3.4549
# Epoch 133/150
# 21/21 [==============================] - 22s 1s/step - loss: 3.4497
# Epoch 134/150
# 21/21 [==============================] - 23s 1s/step - loss: 3.4418
# Epoch 135/150
# 21/21 [==============================] - 24s 1s/step - loss: 3.4433
# Epoch 136/150
# 21/21 [==============================] - 24s 1s/step - loss: 3.4428
# Epoch 137/150
# 21/21 [==============================] - 25s 1s/step - loss: 3.4368
# Epoch 138/150
# 21/21 [==============================] - 25s 1s/step - loss: 3.4298
# Epoch 139/150
# 21/21 [==============================] - 24s 1s/step - loss: 3.4273
# Epoch 140/150
# 21/21 [==============================] - 23s 1s/step - loss: 3.4267
# Epoch 141/150
# 21/21 [==============================] - 22s 1s/step - loss: 3.4259
# Epoch 142/150
# 21/21 [==============================] - 23s 1s/step - loss: 3.4241
# Epoch 143/150
# 21/21 [==============================] - 22s 1s/step - loss: 3.4261
# Epoch 144/150
# 21/21 [==============================] - 24s 1s/step - loss: 3.4217
# Epoch 145/150
# 21/21 [==============================] - 23s 1s/step - loss: 3.4164
# Epoch 146/150
# 21/21 [==============================] - 22s 1s/step - loss: 3.4165
# Epoch 147/150
# 21/21 [==============================] - 27s 1s/step - loss: 3.4171
# Epoch 148/150
# 21/21 [==============================] - 27s 1s/step - loss: 3.4098
# Epoch 149/150
# 21/21 [==============================] - 23s 1s/step - loss: 3.4018
# Epoch 150/150
# 21/21 [==============================] - 25s 1s/step - loss: 3.4016
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 40, 512)           1052672
#
#  dropout_4 (Dropout)         (None, 40, 512)           0
#
#  batch_normalization_4 (Bat  (None, 40, 512)           2048
#  chNormalization)
#
#  lstm_5 (LSTM)               (None, 256)               787456
#
#  dense_4 (Dense)             (None, 256)               65792
#
#  batch_normalization_5 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dropout_5 (Dropout)         (None, 256)               0
#
#  dense_5 (Dense)             (None, 121)               31097
#
# =================================================================
# Total params: 1940089 (7.40 MB)
# Trainable params: 1938553 (7.39 MB)
# Non-trainable params: 1536 (6.00 KB)
# _________________________________________________________________

# %%
from music21 import stream

def Malody_Generator(model, X_seed, reverse_mapping, length, L_symb, Note_Count, user_input, normal):
    
    seed = X_seed[np.random.randint(0, len(X_seed) - 1)]
    Music = ""
    Notes_Generated = []
    
    if(not normal):
        user_input_indices = user_input
        user_input_normalized = np.array(user_input_indices) / float(L_symb)
        user_input_normalized = user_input_normalized[:length]
        seed[-len(user_input_normalized):] = user_input_normalized.reshape(-1, 1)

    for i in range(Note_Count):
        seed = seed.reshape(1, length, 1)
        prediction = model.predict(seed, verbose=0)[0]
        prediction = np.log(prediction) / 1.5  # diversity
        exp_preds = np.exp(prediction)
        prediction = exp_preds / np.sum(exp_preds)
        index = np.argmax(prediction)
        index_N = index / float(L_symb)
        Notes_Generated.append(index)
        Music = [reverse_mapping[char] for char in Notes_Generated]
        seed = np.insert(seed[0], len(seed[0]), index_N)
        seed = seed[1:]

    Melody = chords_n_notes(Music)
    return Music, Melody

user_input = [0,13,128,0,13,12,11,18,1,2,0,13,128,0,13,12,11,18,1,2,0,13,128,0,13,12,11,18,1,2,0,13,128,0,13,12,11,18,1,2,0]
generated_music, generated_melody = Malody_Generator(model, X_seed, reverse_mapping, length, L_symb, 100, user_input, 0)
generated_music_normal, generated_melody_normal = Malody_Generator(model, X_seed, reverse_mapping, length, L_symb, 100, [], 1)
generated_melody.write('midi','Melody_Generated.mid')
generated_melody_normal.write('midi','Melody_Generated_1.mid')
# Out:
# 'Melody_Generated_1.mid'

# %%
## RESULTS

def play_music(file):
    b = music21.converter.parse(file)

    import random
    keyDetune = []
    for i in range(127):
        keyDetune.append(random.randint(-30, 30))

    for n in b.flatten().notesAndRests:
        if isinstance(n, note.Note):
            n.pitch.microtone = keyDetune[n.pitch.midi]
        elif isinstance(n, chord.Chord):
            for note_in_chord in n.pitches:
                note_in_chord.microtone = keyDetune[note_in_chord.midi]

    sp = music21.midi.realtime.StreamPlayer(b)
    sp.play()

    
play_music("g")
